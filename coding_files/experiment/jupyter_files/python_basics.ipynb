# %%
print("Hello, World!") #Print the traditional hello world message to the console

import sys
print(sys.version)

z = 2+15
print(z) #Print the result of the addition to the console

print("Python is \"awesome\"")
# Out:
# Hello, World!
# 3.13.5 (tags/v3.13.5:6cb20a2, Jun 11 2025, 16:15:46) [MSC v.1943 64 bit (AMD64)]
# 17

# %%
type(12.1) #Check the type of the number 12.1, which should be a float
type(0)
type("Hello")
print(float(2))
type(float(2)) #Convert the integer 2 to a float and check its type, which should be float

type(True)
print(int(False))
# Out:
# 2.0
# 0

# %%
print(30+20-40)
print((55-5)/10)
print((6*10)/12)
x=3+2*2
print(x)
y=(3+2)*2
print(y)
z=x+y
print(z)
# Out:
# 10
# 5.0
# 5.0
# 7
# 10
# 17

# %%
name = "Aashutosh"
age = 17
str = f"My name is {name} and I am {age} years old."
print(str)
print("My name is {} and I am {} years old.".format(name, age))
print("My name is %s and I am %d years old." % (name,age))

raw_string = r"This is a raw string with a newline character \n that will not be interpreted."

# %%
import re
s1 = "The BodyGuard is the best album."
pattern = r"Body"

result = re.search(pattern, s1)

if result:
    print('Match Found!')
else:
    print("Match not found.")
# Out:
# Match Found!

# %%
L = ["The Bodyguard", 7.0, 1992, [1, 2], ("A", 1)]
print(L[0],L[-3]) #Accessing the same element +ve and _ve wise
print(L[3:5])
L.extend(['pop',10])
print(L)
del(L[1])
# Out:
# The Bodyguard 1992
# [[1, 2], ('A', 1)]
# ['The Bodyguard', 7.0, 1992, [1, 2], ('A', 1), 'pop', 10]

# %%
a_list = [1, 'hello', [1, 2, 3] , True]
print(a_list[1])
print(a_list[1:4])
A = [1, 'a']
B = [2, 1, 'd']
print(A+B)
# Out:
# hello
# ['hello', [1, 2, 3], True]
# [1, 'a', 2, 1, 'd']

# %%
genres = ("pop", "rock", "soul", "hard rock", "soft rock", "R&B", "progressive rock", "disco") 
print(len(genres))
print(genres[3])
print(genres[3:6])
print(genres[0:2])
print(genres[-1].find('s'))
C = (-5, 1, -3)
print(sorted(C))
# Out:
# 8
# hard rock
# ('hard rock', 'soft rock', 'R&B')
# ('pop', 'rock')
# 2
# [-5, -3, 1]

# %%
soundtrack_dic = {"The Bodyguard":"1992", "Saturday Night Fever":"1977"}
print(soundtrack_dic.keys())
print(soundtrack_dic.values())
print("The Bodyguard" in soundtrack_dic)
# Out:
# dict_keys(['The Bodyguard', 'Saturday Night Fever'])
# dict_values(['1992', '1977'])
# True

# %%
#Sets  
L, s = ['rap','house','electronic music','rap'], set(L)
print(L)
print(s)

A, B = [1, 2, 2, 1], set([1, 2, 2, 1])
x, y = sum(A), sum(B)
print(x==y)

album_set1 = set(["Thriller", 'AC/DC', 'Back in Black'])
album_set2 = set([ "AC/DC", "Back in Black", "The Dark Side of the Moon"])
album_set3 = album_set1 & album_set2
album_set4 = album_set1.union(album_set2)
print(album_set3, album_set4)
print(album_set1.issubset(album_set3))
# Out:
# ['rap', 'house', 'electronic music', 'rap']
# {'house', 'rap', 'electronic music'}
# False
# {'AC/DC', 'Back in Black'} {'AC/DC', 'Thriller', 'Back in Black', 'The Dark Side of the Moon'}
# False

# %%
for i in range(-5,6):
    print(i)

Genres=[ 'rock', 'R&B', 'Soundtrack', 'R&B', 'soul', 'pop']
for j in Genres:
    print(j)

PlayListRatings = [10, 9.5, 10, 8, 7.5, 5, 10, 10]
for k in PlayListRatings:
    while k >= 6:
        print(k)

for i in range(1, 16):
    if i % 3 == 0:
        continue  # skip multiples of 3
    if i > 12:
        break     # stop if number > 12
    print(i)

# %%
for i, x in enumerate(['A', 'B', 'C']):
    print(i, x)

items = ["Vase", "Statue", "Mask"]
for index, item in enumerate(items, start=1):
    print(f"Exhibit {index}: {item} - Ancient Greece")
# Out:
# 0 A
# 1 B
# 2 C
# Exhibit 1: Vase - Ancient Greece
# Exhibit 2: Statue - Ancient Greece
# Exhibit 3: Mask - Ancient Greece

# %%
#Creating a class of circles
class Circle(object):
    def __init__(self, radius, color):
        self.radius = radius
        self.color = color
    def addRadius(self, r):
        self.radius = self.radius + r
        return(self.radius)
c1 = Circle(10, "radius")
print(c1.radius, c1.color)
c1.color = "blue"
print(c1.color)
print(c1.addRadius(5))
print(c1.radius, c1.color)

for i in dir(Circle):
    if i[-1] != '_' and i[0] != '_':
        print(i)
# Out:
# 10 radius
# blue
# 15
# 15 blue
# addRadius

# %%
class Car:
    # Class attribute (shared by all instances)
    max_speed = 120  # Maximum speed in km/h

    # Constructor method (initialize instance attributes)
    def __init__(self, make, model, color, speed=0):
        self.make = make
        self.model = model
        self.color = color
        self.speed = speed  # Initial speed is set to 0

    # Method for accelerating the car
    def accelerate(self, acceleration):
        if self.speed + acceleration <= Car.max_speed:
            self.speed += acceleration
        else:
            self.speed = Car.max_speed

    # Method to get the current speed of the car
    def get_speed(self):
        return self.speed
    
n = int(input('Enter how many cars: '))
for i in range(n):
    mk = input('Enter make: ')
