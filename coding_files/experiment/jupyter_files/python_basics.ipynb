# %%
print("Hello, World!") #Print the traditional hello world message to the console

import sys
print(sys.version)

z = 2+15
print(z) #Print the result of the addition to the console
# Out:
# Hello, World!
# 3.13.5 (tags/v3.13.5:6cb20a2, Jun 11 2025, 16:15:46) [MSC v.1943 64 bit (AMD64)]
# 17

# %%
type(12.1) #Check the type of the number 12.1, which should be a float
type(0)
type("Hello")
print(float(2))
type(float(2)) #Convert the integer 2 to a float and check its type, which should be float

type(True)
print(int(False))
# Out:
# 2.0
# 0

# %%
print(30+20-40)
print((55-5)/10)
print((6*10)/12)
x=3+2*2
print(x)
y=(3+2)*2
print(y)
z=x+y
print(z)
# Out:
# 10
# 5.0
# 5.0
# 7
# 10
# 17
