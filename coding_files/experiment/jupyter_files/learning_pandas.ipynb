# %%
import pandas as pd

# %%
from pyodide.http import pyfetch
filename = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%204/data/example1.txt"
async def download(url, filename):

    response = await pyfetch(url)

    if response.status == 200:

        with open(filename, "wb") as f:

            f.write(await response.bytes())

await download(filename, "example1.txt")

print("done")

# %%
songs = {'Album' : ['Thriller','Back in Black','The Dark Side of the Moon',\
'The Bodyguard','Bat Out of Hell'],
'Released' : [1982,1980,1973,1992,1977],
'Length' : ['00:42:19','00:42:11','00:42:49','00:57:44','00:46:33']}

df = pd.DataFrame(songs)
print(df)
# Out:
#                        Album  Released    Length
# 0                   Thriller      1982  00:42:19
# 1              Back in Black      1980  00:42:11
# 2  The Dark Side of the Moon      1973  00:42:49
# 3              The Bodyguard      1992  00:57:44
# 4            Bat Out of Hell      1977  00:46:33

# %%
path = r'C:\Aashutosh\Career_OS\01_courses\IBM_AI_course\ibm_data_science_coursework\coding_files\experiment\test_files\bunker_oil_consumption.csv'
df = pd.read_csv(path)
h = df.head()

h
# Out:
#                       API bunker fuel consumption (Mb/d)  1980   1981   1982  \
# 0  INTL.54-13-WORL-TBPD.A                          World   NaN  896.0  742.0
# 1   INTL.54-13-AFG-TBPD.A                    Afghanistan   NaN    NaN    NaN
# 2   INTL.54-13-ALB-TBPD.A                        Albania   NaN    NaN    NaN
# 3   INTL.54-13-DZA-TBPD.A                        Algeria   NaN    NaN    NaN
# 4   INTL.54-13-ASM-TBPD.A                 American Samoa   NaN    NaN    NaN
#
#     1983   1984   1985    1986    1987  ...         2006         2007  \
# 0  675.0  677.4  715.6  1790.2  1765.8  ...  4569.506305  4918.653863
# 1    NaN    NaN    NaN     0.3     0.2  ...          0.2          0.2
# 2    NaN    NaN    NaN       0       0  ...          1.8          2.2
# 3    NaN    NaN    NaN      15     8.9  ...           14           14
# 4    NaN    NaN    NaN       0       0  ...            2            2
#
#           2008         2009         2010         2011         2012  \
# ...

# %%
file_path = r'C:\Aashutosh\Career_OS\01_courses\IBM_AI_course\ibm_data_science_coursework\coding_files\experiment\test_files\albums.csv'
df = pd.read_csv(file_path)

h = df.head()
x = df[['Artist', 'Length','Genre']] # Table with specified columns
mj = df.iloc[0,0]
ac = df.loc[1,'Artist']
# have to use iloc (integer location) to locate any specific value: format is DataFrame.iloc[row,column]
df_new = df
df_new.index = ['a','b','c','d','e','f','h','i']
z = df.iloc[0:2, 0:3] # Returns string

df1 =  df[df['Released'] > 1979] # Returns table showing only rows that correspond to the condition
path1 = r'C:\Aashutosh\Career_OS\01_courses\IBM_AI_course\ibm_data_science_coursework\coding_files\experiment\test_files\new_songs.csv'
df1.to_csv(path1)

u_art = df['Artist'].unique() #Gives a List of Strings

high_above_102 = df['Released']>1979 #Returns column of Boolean Values
