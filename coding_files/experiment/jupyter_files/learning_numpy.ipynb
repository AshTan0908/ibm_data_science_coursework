# %%
import numpy as np
l = [0, 1, 2, 3, 4, 5]
a = np.array(l)

type(a) # <class 'numpy.ndarray'>
print(a)
x = a.dtype # type of array elements
print(x)
print(a.size) # basically len() for arrays
print(a.ndim) # dimensions of array
print(a.shape) # length of each dimension

c = np.array([100,1,2,3,0])
d = c[3:5]
c[3:5] = 300,200

c, d
# Out:
# [0 1 2 3 4 5]
# int64
# 6
# 1
# (6,)
# (array([100,   1,   2, 300, 200]), array([300, 200]))

# %%
# Adding vectors like matrix addition
# Using normal Python Lists and Code (Slow)
u = [1, 0]
v = [0, 1]
z = []
for n, m in zip(u,v):
    z.append(n+m) # can also use - or *
z
# Out:
# [2, 0]

# %%
# Vector Addition using NumPy and Arrays (Much Faster than Normal Python)
import numpy
u = numpy.array([1, 0])
v = numpy.array([0, 1])
z1 = u+v # or numpy.add(u, v)
z2 = u-v # or numpy.subtract(u, v)
z1, z2

n = numpy.array([1,2])
y1 = n*2
y1

# Hadamard Product
a = numpy.array([1,2])
b = numpy.array([3,2])
y2 = a*b # or numpy.multiply(a, b)
result = numpy.dot(a,b)
result

# Broadcasting
p = numpy.array([1,2,3,-1])
z3 = p + 1
z3
mean = p.mean()
maxi = p.max()

# Working with Radians
x = numpy.array([0, numpy.pi/2, numpy.pi])
print(x)
y = numpy.sin(x)
print(y)
# Out:
# [0.         1.57079633 3.14159265]
# [0.0000000e+00 1.0000000e+00 1.2246468e-16]
# array([0.        , 1.57079633, 3.14159265])

# %%
arr1 = np.array([1, 2, 3])
print(arr1)
for x in arr1:
    print(x)
# Out:
# [1 2 3]
# 1
# 2
# 3

# %%
import numpy as np
# Using line space to plot functions
x1 = np.linspace(-2,2,num = 5) # numpy.linspace(start, end, number of sample spaces)
x2 = np.linspace(-2,2,num = 9)

# Plotting mathematical functions
y1 = np.linspace(0, 2*np.pi, 100)
y2 = np.sin(y1)
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(y1, y2)

# %%
import time 
import sys
import numpy as np 

import matplotlib.pyplot as plt


def Plotvec1(u, z, v):
    ax = plt.axes() # to generate the full window axes
    ax.arrow(0, 0, *u, head_width=0.05, color='r', head_length=0.1)# Add an arrow to the  U Axes with arrow head width 0.05, color red and arrow head length 0.1
    plt.text(*(u + 0.1), 'u')#Adds the text u to the Axes 
    
    ax.arrow(0, 0, *v, head_width=0.05, color='b', head_length=0.1)# Add an arrow to the  v Axes with arrow head width 0.05, color red and arrow head length 0.1
    plt.text(*(v + 0.1), 'v')#Adds the text v to the Axes 
    
    ax.arrow(0, 0, *z, head_width=0.05, head_length=0.1)
    plt.text(*(z + 0.1), 'z')#Adds the text z to the Axes 
    plt.ylim(-2, 2)#set the ylim to bottom(-2), top(2)
    plt.xlim(-2, 2)#set the xlim to left(-2), right(2)
Plotvec1(u, z, v)

# %%
import time 
import sys
import numpy as np 

import matplotlib.pyplot as plt


def Plotvec2(a,b):
    ax = plt.axes()# to generate the full window axes
    ax.arrow(0, 0, *a, head_width=0.05, color ='r', head_length=0.1)#Add an arrow to the  a Axes with arrow head width 0.05, color red and arrow head length 0.1
    plt.text(*(a + 0.1), 'a')
    ax.arrow(0, 0, *b, head_width=0.05, color ='b', head_length=0.1)#Add an arrow to the  b Axes with arrow head width 0.05, color blue and arrow head length 0.1
    plt.text(*(b + 0.1), 'b')
    plt.ylim(-2, 2)#set the ylim to bottom(-2), top(2)
    plt.xlim(-2, 2)#set the xlim to left(-2), right(2)

x = np.array([1,1])
y = np.array([0,1])
Plotvec2(x,y)

# %%
import numpy as np
A=np.array([[0,1,1],[1,0,1]])
B=np.array([[1,1],[1,1],[-1,1]])

C=np.dot(A,B)
tran_A = A.T
C, tran_A
# Out:
# (array([[0, 2],
#         [0, 2]]),
#  array([[0, 1],
#         [1, 0],
#         [1, 1]]))
