# %% [markdown]
# # Heading 1 - Main Title
# ## Heading 2 - Subsection
# ### Heading 3 - Sub-subsection
#
# ### Text Formatting
# This is **bold text** and this is *italic text*.
# You can also do ***bold italic***, ~~strikethrough~~, and `inline code`.
#
# ### Lists
# **Unordered List:**
# - First item
# - Second item
#   - Nested item
# - Third item
#
# **Ordered List:**
# 1. First step
# 2. Second step
# 3. Third step
#
# ### Links and Images
# [This is a link to Google](https://www.google.com)
#
# ### Blockquotes
# > This is a blockquote.
# > It can span multiple lines.

# %% [markdown]
# # My first Markdown
# Hello world!

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# x=2
# print(x*3.5)
# print(x+2)

# %%
4.5
# Out:
# 4.5

# %%
#Execute this cell by using the Shift + Enter shortcut
l = [1,3,2,5,4]
print(max(l))
print(sorted(l))
# Out:
# 5
# [1, 2, 3, 4, 5]

# %% [markdown]
# ## Evaluating Basic Arithmetic Expression

# %%
print((20+5)*4)
# Out:
# 100

# %%
#Displaying a string message. 
print("Let us explore python without coding.")
# Out:
# Let us explore python without coding.

# %%
## Click after 1+1 in this cell and split it
1+1

# %%
2*2
